# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.base import clone

from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# %%
def make_synthetic_dataset(n_features=50, n_informative=10, n_redundant=15, n_samples=10000):
    from sklearn.datasets import make_classification
    # n_informative features, followed by n_redundant, followed by n_repeated duplicates
    X, y = make_classification(n_samples=n_samples, n_features=n_features, n_informative=n_informative,\
                               n_redundant=n_redundant, shuffle=False, random_state=1711)
    cols = []
    n_noise = n_features - n_informative - n_redundant
    for i in range(n_informative):
        cols.append("I" + str(i))
    for i in range(n_redundant):
        cols.append("R" + str(i))
    for i in range(n_noise):
        cols.append("N" + str(i))

    X_df = pd.DataFrame(data=X, columns=cols)
    Y_series = pd.Series(y)
    
    return X_df, Y_series

# %%
X, y = make_synthetic_dataset()

# %% [markdown]
# #### Plot features with PCA explained variance

# %%
def run_pca(df):
    pca = PCA() # Plotting the explained variance and look for the drastic decrease
    df_normalized = (df - df.mean()) / df.std()
    pca.fit(df_normalized)
    
    pca_cols = ['PCA' + str(i) for i in range(df.shape[1])]
    pca_col_variance = list(zip(pca_cols, pca.explained_variance_))
    pca_col_variance.sort(key=lambda x: (x[1], x[0]))
    pca_cols, pca_variances = list(zip(*pca_col_variance))

    return pca_cols, pca_variances

# %%
pca_cols, pca_variances = run_pca(X)

# %%
fig, ax = plt.subplots(figsize=(18, 15))
ax.barh(pca_cols, pca_variances)
# Out:
# <BarContainer object of 50 artists>

# %% [markdown]
# #### Plot features with MDI on RF

# %%
def run_mdi(X, y, rf):
    rf.fit(X, y)
    rf_mdi_feature_scores = list(zip(rf.feature_names_in_, rf.feature_importances_))
    rf_mdi_feature_scores.sort(key=lambda x: (x[1], x[0]))
    rf_features, rf_mdi = list(zip(*rf_mdi_feature_scores))

    return rf_features, rf_mdi

# %%
rf = RandomForestClassifier(random_state=1711)
rf_features, rf_mdi = run_mdi(X, y, rf)

# %%
fig, ax = plt.subplots(figsize=(18, 10))
ax.barh(rf_features, rf_mdi)
# Out:
# <BarContainer object of 50 artists>

# %% [markdown]
# #### Plot features with MDA using RF

# %%
def run_mda(X, y, clf, cv_folds=5):
    clf = clone(clf)
    baseline_accuracy = np.mean(cross_val_score(clf, X, y, cv=cv_folds, n_jobs=-1))
    print("Baseline Accurarcy = {:.4f}".format(baseline_accuracy))

    mda_score_list = []
    for feature in X.columns:
        clf = clone(clf)
        X_shuffle = X.copy()
        X_shuffle[feature] = np.random.permutation(X_shuffle[feature])
        accuracy = np.mean(cross_val_score(clf, X_shuffle, y, cv=cv_folds, n_jobs=-1))
        accuracy_diff = baseline_accuracy - accuracy
        mda_score_list.append((feature, accuracy_diff))
        print("Traing with shuffling feature {}, with accuracy={:.4f} and difference={:.4f}".format(feature, accuracy, accuracy_diff))

    mda_score_list.sort(key=lambda x: (x[1], x[0]), reverse=True)
    mda_features, mda_scores = list(zip(*mda_score_list))

    return mda_features, mda_scores

# %%
rf = RandomForestClassifier(random_state=1711)
mda_features, mda_scores = run_mda(X, y, rf)
# Out:
# Baseline Accurarcy = 0.9243
# Traing with shuffling feature I0, with accuracy=0.9232 and difference=0.0011
# Traing with shuffling feature I1, with accuracy=0.9225 and difference=0.0018
# Traing with shuffling feature I2, with accuracy=0.9221 and difference=0.0022
# Traing with shuffling feature I3, with accuracy=0.9219 and difference=0.0024
# Traing with shuffling feature I4, with accuracy=0.9233 and difference=0.0010
# Traing with shuffling feature I5, with accuracy=0.9227 and difference=0.0016
# Traing with shuffling feature I6, with accuracy=0.9184 and difference=0.0059
# Traing with shuffling feature I7, with accuracy=0.9208 and difference=0.0035
# Traing with shuffling feature I8, with accuracy=0.9271 and difference=-0.0028
# Traing with shuffling feature I9, with accuracy=0.9237 and difference=0.0006
# Traing with shuffling feature R0, with accuracy=0.9241 and difference=0.0002
# Traing with shuffling feature R1, with accuracy=0.9229 and difference=0.0014
# Traing with shuffling feature R2, with accuracy=0.9242 and difference=0.0001
# Traing with shuffling feature R3, with accuracy=0.9227 and difference=0.0016
# Traing with shuffling feature R4, with accuracy=0.9212 and difference=0.0031
# Traing with shuffling feature R5, with accuracy=0.9235 and difference=0.0008
# Traing with shuffling feature R6, with accuracy=0.9235 and difference=0.0008
# Traing with shuffling feature R7, with accuracy=0.9247 and difference=-0.0004
# Traing with shuffling feature R8, with accuracy=0.9250 and difference=-0.0007
# Traing with shuffling feature R9, with accuracy=0.9243 and difference=0.0000
# Traing with shuffling feature R10, with accuracy=0.9235 and difference=0.0008
# Traing with shuffling feature R11, with accuracy=0.9246 and difference=-0.0003
# Traing with shuffling feature R12, with accuracy=0.9257 and difference=-0.0014
# Traing with shuffling feature R13, with accuracy=0.9235 and difference=0.0008
# Traing with shuffling feature R14, with accuracy=0.9209 and difference=0.0034
# Traing with shuffling feature N0, with accuracy=0.9242 and difference=0.0001
# Traing with shuffling feature N1, with accuracy=0.9243 and difference=0.0000
# Traing with shuffling feature N2, with accuracy=0.9239 and difference=0.0004
# Traing with shuffling feature N3, with accuracy=0.9246 and difference=-0.0003
# Traing with shuffling feature N4, with accuracy=0.9245 and difference=-0.0002
# Traing with shuffling feature N5, with accuracy=0.9248 and difference=-0.0005
# Traing with shuffling feature N6, with accuracy=0.9257 and difference=-0.0014
# Traing with shuffling feature N7, with accuracy=0.9242 and difference=0.0001
# Traing with shuffling feature N8, with accuracy=0.9252 and difference=-0.0009
# Traing with shuffling feature N9, with accuracy=0.9205 and difference=0.0038
# Traing with shuffling feature N10, with accuracy=0.9250 and difference=-0.0007
# Traing with shuffling feature N11, with accuracy=0.9231 and difference=0.0012
# Traing with shuffling feature N12, with accuracy=0.9246 and difference=-0.0003
# Traing with shuffling feature N13, with accuracy=0.9244 and difference=-0.0001
# Traing with shuffling feature N14, with accuracy=0.9248 and difference=-0.0005
# Traing with shuffling feature N15, with accuracy=0.9226 and difference=0.0017
# Traing with shuffling feature N16, with accuracy=0.9255 and difference=-0.0012
# Traing with shuffling feature N17, with accuracy=0.9247 and difference=-0.0004
# Traing with shuffling feature N18, with accuracy=0.9235 and difference=0.0008
# Traing with shuffling feature N19, with accuracy=0.9231 and difference=0.0012
# Traing with shuffling feature N20, with accuracy=0.9233 and difference=0.0010
# Traing with shuffling feature N21, with accuracy=0.9232 and difference=0.0011
# Traing with shuffling feature N22, with accuracy=0.9252 and difference=-0.0009
# Traing with shuffling feature N23, with accuracy=0.9251 and difference=-0.0008
# Traing with shuffling feature N24, with accuracy=0.9235 and difference=0.0008

# %%
fig, ax = plt.subplots(figsize=(18, 15))
ax.barh(mda_features, mda_scores)
# Out:
# <BarContainer object of 50 artists>

# %% [markdown]
# #### Plot features with SFI using RF

# %%
def run_sfi(X, y, clf, cv_folds=5):
    clf = clone(clf)
    baseline_accuracy = np.mean(cross_val_score(clf, X, y, cv=cv_folds, n_jobs=-1))
    print("Baseline Accurarcy = {:.4f}".format(baseline_accuracy))
    
    sfi_score_list = []
    for feature in X.columns:
        clf = clone(clf)
        accuracy = np.mean(cross_val_score(clf, X[[feature]], y, cv=cv_folds, n_jobs=-1))
        accuracy_diff = baseline_accuracy - accuracy
        sfi_score_list.append((feature, accuracy_diff))
        print("Traing RF on the single feature {}, with accuracy={:.4f} and difference={:.4f}".format(feature, accuracy, accuracy_diff))

    sfi_score_list.sort(key=lambda x: (x[1], x[0]), reverse=True)
    sfi_features, sfi_scores = list(zip(*sfi_score_list))

    return sfi_features, sfi_scores

# %%
rf = RandomForestClassifier(random_state=1711)
sfi_features, sfi_scores = run_sfi(X, y, rf)
# Out:
# Baseline Accurarcy = 0.9243
# Traing RF on the single feature I0, with accuracy=0.5522 and difference=0.3721
# Traing RF on the single feature I1, with accuracy=0.5550 and difference=0.3693
# Traing RF on the single feature I2, with accuracy=0.4978 and difference=0.4265
# Traing RF on the single feature I3, with accuracy=0.5373 and difference=0.3870
# Traing RF on the single feature I4, with accuracy=0.4926 and difference=0.4317
# Traing RF on the single feature I5, with accuracy=0.4952 and difference=0.4291
# Traing RF on the single feature I6, with accuracy=0.5431 and difference=0.3812
# Traing RF on the single feature I7, with accuracy=0.5298 and difference=0.3945
# Traing RF on the single feature I8, with accuracy=0.6180 and difference=0.3063
# Traing RF on the single feature I9, with accuracy=0.5373 and difference=0.3870
# Traing RF on the single feature R0, with accuracy=0.4997 and difference=0.4246
# Traing RF on the single feature R1, with accuracy=0.5856 and difference=0.3387
# Traing RF on the single feature R2, with accuracy=0.5402 and difference=0.3841
# Traing RF on the single feature R3, with accuracy=0.5881 and difference=0.3362
# Traing RF on the single feature R4, with accuracy=0.5217 and difference=0.4026
# Traing RF on the single feature R5, with accuracy=0.5418 and difference=0.3825
# Traing RF on the single feature R6, with accuracy=0.5885 and difference=0.3358
# Traing RF on the single feature R7, with accuracy=0.5024 and difference=0.4219
# Traing RF on the single feature R8, with accuracy=0.5060 and difference=0.4183
# Traing RF on the single feature R9, with accuracy=0.5354 and difference=0.3889
# Traing RF on the single feature R10, with accuracy=0.4885 and difference=0.4358
# Traing RF on the single feature R11, with accuracy=0.5757 and difference=0.3486
# Traing RF on the single feature R12, with accuracy=0.5424 and difference=0.3819
# Traing RF on the single feature R13, with accuracy=0.5346 and difference=0.3897
# Traing RF on the single feature R14, with accuracy=0.5337 and difference=0.3906
# Traing RF on the single feature N0, with accuracy=0.5086 and difference=0.4157
# Traing RF on the single feature N1, with accuracy=0.5057 and difference=0.4186
# Traing RF on the single feature N2, with accuracy=0.5017 and difference=0.4226
# Traing RF on the single feature N3, with accuracy=0.5033 and difference=0.4210
# Traing RF on the single feature N4, with accuracy=0.4960 and difference=0.4283
# Traing RF on the single feature N5, with accuracy=0.4804 and difference=0.4439
# Traing RF on the single feature N6, with accuracy=0.5063 and difference=0.4180
# Traing RF on the single feature N7, with accuracy=0.5030 and difference=0.4213
# Traing RF on the single feature N8, with accuracy=0.4935 and difference=0.4308
# Traing RF on the single feature N9, with accuracy=0.4973 and difference=0.4270
# Traing RF on the single feature N10, with accuracy=0.5050 and difference=0.4193
# Traing RF on the single feature N11, with accuracy=0.5009 and difference=0.4234
# Traing RF on the single feature N12, with accuracy=0.4987 and difference=0.4256
# Traing RF on the single feature N13, with accuracy=0.5013 and difference=0.4230
# Traing RF on the single feature N14, with accuracy=0.4928 and difference=0.4315
# Traing RF on the single feature N15, with accuracy=0.5055 and difference=0.4188
# Traing RF on the single feature N16, with accuracy=0.4868 and difference=0.4375
# Traing RF on the single feature N17, with accuracy=0.4990 and difference=0.4253
# Traing RF on the single feature N18, with accuracy=0.4960 and difference=0.4283
# Traing RF on the single feature N19, with accuracy=0.4998 and difference=0.4245
# Traing RF on the single feature N20, with accuracy=0.4912 and difference=0.4331
# Traing RF on the single feature N21, with accuracy=0.5033 and difference=0.4210
# Traing RF on the single feature N22, with accuracy=0.5046 and difference=0.4197
# Traing RF on the single feature N23, with accuracy=0.4905 and difference=0.4338
# Traing RF on the single feature N24, with accuracy=0.5171 and difference=0.4072

# %%
fig, ax = plt.subplots(figsize=(18, 15))
ax.barh(sfi_features, sfi_scores)
# Out:
# <BarContainer object of 50 artists>

# %% [markdown]
# ### Combine PCA-transformed dataset with the original

# %%
n_pca_components = 34
pca = PCA(n_components=n_pca_components)
X_standardized = (X - X.mean()) / X.std()

X_pca = pca.fit_transform(X_standardized)
X_pca = pd.DataFrame(X_pca, columns=['PCA_' + str(i) for i in range(n_pca_components)])
X_pca_combine = pd.concat([X_standardized, X_pca], axis=1)

print("X_standardized.shape={}".format(X_standardized.shape))
print("X_pca.shape={}".format(X_pca.shape))
print("X_pca_combine.shape={}".format(X_pca_combine.shape))
print("X_pca_combine.columns={}".format(X_pca_combine.columns))
# Out:
# X_standardized.shape=(10000, 50)
# X_pca.shape=(10000, 34)
# X_pca_combine.shape=(10000, 84)
# X_pca_combine.columns=Index(['I0', 'I1', 'I2', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9', 'R0', 'R1',
#        'R2', 'R3', 'R4', 'R5', 'R6', 'R7', 'R8', 'R9', 'R10', 'R11', 'R12',
#        'R13', 'R14', 'N0', 'N1', 'N2', 'N3', 'N4', 'N5', 'N6', 'N7', 'N8',
#        'N9', 'N10', 'N11', 'N12', 'N13', 'N14', 'N15', 'N16', 'N17', 'N18',
#        'N19', 'N20', 'N21', 'N22', 'N23', 'N24', 'PCA_0', 'PCA_1', 'PCA_2',
#        'PCA_3', 'PCA_4', 'PCA_5', 'PCA_6', 'PCA_7', 'PCA_8', 'PCA_9', 'PCA_10',
#        'PCA_11', 'PCA_12', 'PCA_13', 'PCA_14', 'PCA_15', 'PCA_16', 'PCA_17',
#        'PCA_18', 'PCA_19', 'PCA_20', 'PCA_21', 'PCA_22', 'PCA_23', 'PCA_24',
#        'PCA_25', 'PCA_26', 'PCA_27', 'PCA_28', 'PCA_29', 'PCA_30', 'PCA_31',
#        'PCA_32', 'PCA_33'],
#       dtype='object')

# %% [markdown]
# Run MDI using RF

# %%
rf = RandomForestClassifier(random_state=1711)
rf_features, rf_mdi = run_mdi(X_pca_combine, y, rf)
fig, ax = plt.subplots(figsize=(18, 25))
ax.barh(rf_features, rf_mdi)
# Out:
# <BarContainer object of 84 artists>

# %% [markdown]
# Run MDA using RF

# %%
rf = RandomForestClassifier(random_state=1711)
mda_features, mda_scores = run_mda(X_pca_combine, y, rf)
fig, ax = plt.subplots(figsize=(18, 25))
ax.barh(mda_features, mda_scores)
# Out:
# Baseline Accurarcy = 0.9251
# Traing with shuffling feature I0, with accuracy=0.9250 and difference=0.0001
# Traing with shuffling feature I1, with accuracy=0.9232 and difference=0.0019
# Traing with shuffling feature I2, with accuracy=0.9229 and difference=0.0022
# Traing with shuffling feature I3, with accuracy=0.9220 and difference=0.0031
# Traing with shuffling feature I4, with accuracy=0.9244 and difference=0.0007
# Traing with shuffling feature I5, with accuracy=0.9223 and difference=0.0028
# Traing with shuffling feature I6, with accuracy=0.9219 and difference=0.0032
# Traing with shuffling feature I7, with accuracy=0.9214 and difference=0.0037
# Traing with shuffling feature I8, with accuracy=0.9272 and difference=-0.0021
# Traing with shuffling feature I9, with accuracy=0.9243 and difference=0.0008
# Traing with shuffling feature R0, with accuracy=0.9239 and difference=0.0012
# Traing with shuffling feature R1, with accuracy=0.9236 and difference=0.0015
# Traing with shuffling feature R2, with accuracy=0.9244 and difference=0.0007
# Traing with shuffling feature R3, with accuracy=0.9244 and difference=0.0007
# Traing with shuffling feature R4, with accuracy=0.9231 and difference=0.0020
# Traing with shuffling feature R5, with accuracy=0.9240 and difference=0.0011
# Traing with shuffling feature R6, with accuracy=0.9239 and difference=0.0012
# Traing with shuffling feature R7, with accuracy=0.9233 and difference=0.0018
# Traing with shuffling feature R8, with accuracy=0.9255 and difference=-0.0004
# Traing with shuffling feature R9, with accuracy=0.9227 and difference=0.0024
# Traing with shuffling feature R10, with accuracy=0.9236 and difference=0.0015
# Traing with shuffling feature R11, with accuracy=0.9271 and difference=-0.0020
# Traing with shuffling feature R12, with accuracy=0.9248 and difference=0.0003
# Traing with shuffling feature R13, with accuracy=0.9217 and difference=0.0034
# Traing with shuffling feature R14, with accuracy=0.9231 and difference=0.0020
# Traing with shuffling feature N0, with accuracy=0.9256 and difference=-0.0005
# Traing with shuffling feature N1, with accuracy=0.9255 and difference=-0.0004
# Traing with shuffling feature N2, with accuracy=0.9234 and difference=0.0017
# Traing with shuffling feature N3, with accuracy=0.9268 and difference=-0.0017
# Traing with shuffling feature N4, with accuracy=0.9253 and difference=-0.0002
# Traing with shuffling feature N5, with accuracy=0.9255 and difference=-0.0004
# Traing with shuffling feature N6, with accuracy=0.9263 and difference=-0.0012
# Traing with shuffling feature N7, with accuracy=0.9257 and difference=-0.0006
# Traing with shuffling feature N8, with accuracy=0.9260 and difference=-0.0009
# Traing with shuffling feature N9, with accuracy=0.9242 and difference=0.0009
# Traing with shuffling feature N10, with accuracy=0.9260 and difference=-0.0009
# Traing with shuffling feature N11, with accuracy=0.9271 and difference=-0.0020
# Traing with shuffling feature N12, with accuracy=0.9271 and difference=-0.0020
# Traing with shuffling feature N13, with accuracy=0.9262 and difference=-0.0011
# Traing with shuffling feature N14, with accuracy=0.9250 and difference=0.0001
# Traing with shuffling feature N15, with accuracy=0.9260 and difference=-0.0009
# Traing with shuffling feature N16, with accuracy=0.9245 and difference=0.0006
# Traing with shuffling feature N17, with accuracy=0.9240 and difference=0.0011
# Traing with shuffling feature N18, with accuracy=0.9246 and difference=0.0005
# Traing with shuffling feature N19, with accuracy=0.9268 and difference=-0.0017
# Traing with shuffling feature N20, with accuracy=0.9257 and difference=-0.0006
# Traing with shuffling feature N21, with accuracy=0.9238 and difference=0.0013
# Traing with shuffling feature N22, with accuracy=0.9230 and difference=0.0021
# Traing with shuffling feature N23, with accuracy=0.9253 and difference=-0.0002
# Traing with shuffling feature N24, with accuracy=0.9268 and difference=-0.0017
# Traing with shuffling feature PCA_0, with accuracy=0.9249 and difference=0.0002
# Traing with shuffling feature PCA_1, with accuracy=0.9256 and difference=-0.0005
# Traing with shuffling feature PCA_2, with accuracy=0.9237 and difference=0.0014
# Traing with shuffling feature PCA_3, with accuracy=0.9254 and difference=-0.0003
# Traing with shuffling feature PCA_4, with accuracy=0.9227 and difference=0.0024
# Traing with shuffling feature PCA_5, with accuracy=0.9232 and difference=0.0019
# Traing with shuffling feature PCA_6, with accuracy=0.9233 and difference=0.0018
# Traing with shuffling feature PCA_7, with accuracy=0.9246 and difference=0.0005
# Traing with shuffling feature PCA_8, with accuracy=0.9262 and difference=-0.0011
# Traing with shuffling feature PCA_9, with accuracy=0.9241 and difference=0.0010
# Traing with shuffling feature PCA_10, with accuracy=0.9256 and difference=-0.0005
# Traing with shuffling feature PCA_11, with accuracy=0.9260 and difference=-0.0009
# Traing with shuffling feature PCA_12, with accuracy=0.9236 and difference=0.0015
# Traing with shuffling feature PCA_13, with accuracy=0.9251 and difference=0.0000
# Traing with shuffling feature PCA_14, with accuracy=0.9262 and difference=-0.0011
# Traing with shuffling feature PCA_15, with accuracy=0.9246 and difference=0.0005
# Traing with shuffling feature PCA_16, with accuracy=0.9245 and difference=0.0006
# Traing with shuffling feature PCA_17, with accuracy=0.9250 and difference=0.0001
# Traing with shuffling feature PCA_18, with accuracy=0.9234 and difference=0.0017
# Traing with shuffling feature PCA_19, with accuracy=0.9242 and difference=0.0009
# Traing with shuffling feature PCA_20, with accuracy=0.9262 and difference=-0.0011
# Traing with shuffling feature PCA_21, with accuracy=0.9272 and difference=-0.0021
# Traing with shuffling feature PCA_22, with accuracy=0.9259 and difference=-0.0008
# Traing with shuffling feature PCA_23, with accuracy=0.9254 and difference=-0.0003
# Traing with shuffling feature PCA_24, with accuracy=0.9249 and difference=0.0002
# Traing with shuffling feature PCA_25, with accuracy=0.9269 and difference=-0.0018
# Traing with shuffling feature PCA_26, with accuracy=0.9259 and difference=-0.0008
# Traing with shuffling feature PCA_27, with accuracy=0.9249 and difference=0.0002
# Traing with shuffling feature PCA_28, with accuracy=0.9265 and difference=-0.0014
# Traing with shuffling feature PCA_29, with accuracy=0.9252 and difference=-0.0001
# Traing with shuffling feature PCA_30, with accuracy=0.9243 and difference=0.0008
# Traing with shuffling feature PCA_31, with accuracy=0.9228 and difference=0.0023
# Traing with shuffling feature PCA_32, with accuracy=0.9246 and difference=0.0005
# Traing with shuffling feature PCA_33, with accuracy=0.9224 and difference=0.0027
# <BarContainer object of 84 artists>

# %% [markdown]
# Run SFI using RF

# %%
rf = RandomForestClassifier(random_state=1711)
sfi_features, sfi_scores = run_sfi(X_pca_combine, y, rf)
fig, ax = plt.subplots(figsize=(18, 25))
ax.barh(sfi_features, sfi_scores)
# Out:
# Baseline Accurarcy = 0.9251
# Traing RF on the single feature I0, with accuracy=0.5523 and difference=0.3728
# Traing RF on the single feature I1, with accuracy=0.5550 and difference=0.3701
# Traing RF on the single feature I2, with accuracy=0.4978 and difference=0.4273
# Traing RF on the single feature I3, with accuracy=0.5373 and difference=0.3878
# Traing RF on the single feature I4, with accuracy=0.4926 and difference=0.4325
# Traing RF on the single feature I5, with accuracy=0.4952 and difference=0.4299
# Traing RF on the single feature I6, with accuracy=0.5431 and difference=0.3820
# Traing RF on the single feature I7, with accuracy=0.5298 and difference=0.3953
# Traing RF on the single feature I8, with accuracy=0.6180 and difference=0.3071
# Traing RF on the single feature I9, with accuracy=0.5373 and difference=0.3878
# Traing RF on the single feature R0, with accuracy=0.4997 and difference=0.4254
# Traing RF on the single feature R1, with accuracy=0.5856 and difference=0.3395
# Traing RF on the single feature R2, with accuracy=0.5401 and difference=0.3850
# Traing RF on the single feature R3, with accuracy=0.5881 and difference=0.3370
# Traing RF on the single feature R4, with accuracy=0.5217 and difference=0.4034
# Traing RF on the single feature R5, with accuracy=0.5417 and difference=0.3834
# Traing RF on the single feature R6, with accuracy=0.5885 and difference=0.3366
# Traing RF on the single feature R7, with accuracy=0.5024 and difference=0.4227
# Traing RF on the single feature R8, with accuracy=0.5059 and difference=0.4192
# Traing RF on the single feature R9, with accuracy=0.5353 and difference=0.3898
# Traing RF on the single feature R10, with accuracy=0.4887 and difference=0.4364
# Traing RF on the single feature R11, with accuracy=0.5757 and difference=0.3494
# Traing RF on the single feature R12, with accuracy=0.5424 and difference=0.3827
# Traing RF on the single feature R13, with accuracy=0.5345 and difference=0.3906
# Traing RF on the single feature R14, with accuracy=0.5336 and difference=0.3915
# Traing RF on the single feature N0, with accuracy=0.5086 and difference=0.4165
# Traing RF on the single feature N1, with accuracy=0.5057 and difference=0.4194
# Traing RF on the single feature N2, with accuracy=0.5017 and difference=0.4234
# Traing RF on the single feature N3, with accuracy=0.5033 and difference=0.4218
# Traing RF on the single feature N4, with accuracy=0.4961 and difference=0.4290
# Traing RF on the single feature N5, with accuracy=0.4804 and difference=0.4447
# Traing RF on the single feature N6, with accuracy=0.5063 and difference=0.4188
# Traing RF on the single feature N7, with accuracy=0.5030 and difference=0.4221
# Traing RF on the single feature N8, with accuracy=0.4935 and difference=0.4316
# Traing RF on the single feature N9, with accuracy=0.4974 and difference=0.4277
# Traing RF on the single feature N10, with accuracy=0.5049 and difference=0.4202
# Traing RF on the single feature N11, with accuracy=0.5009 and difference=0.4242
# Traing RF on the single feature N12, with accuracy=0.4987 and difference=0.4264
# Traing RF on the single feature N13, with accuracy=0.5012 and difference=0.4239
# Traing RF on the single feature N14, with accuracy=0.4927 and difference=0.4324
# Traing RF on the single feature N15, with accuracy=0.5055 and difference=0.4196
# Traing RF on the single feature N16, with accuracy=0.4868 and difference=0.4383
# Traing RF on the single feature N17, with accuracy=0.4989 and difference=0.4262
# Traing RF on the single feature N18, with accuracy=0.4960 and difference=0.4291
# Traing RF on the single feature N19, with accuracy=0.4998 and difference=0.4253
# Traing RF on the single feature N20, with accuracy=0.4911 and difference=0.4340
# Traing RF on the single feature N21, with accuracy=0.5032 and difference=0.4219
# Traing RF on the single feature N22, with accuracy=0.5045 and difference=0.4206
# Traing RF on the single feature N23, with accuracy=0.4905 and difference=0.4346
# Traing RF on the single feature N24, with accuracy=0.5171 and difference=0.4080
# Traing RF on the single feature PCA_0, with accuracy=0.5853 and difference=0.3398
# Traing RF on the single feature PCA_1, with accuracy=0.5348 and difference=0.3903
# Traing RF on the single feature PCA_2, with accuracy=0.5156 and difference=0.4095
# Traing RF on the single feature PCA_3, with accuracy=0.4937 and difference=0.4314
# Traing RF on the single feature PCA_4, with accuracy=0.5409 and difference=0.3842
# Traing RF on the single feature PCA_5, with accuracy=0.5198 and difference=0.4053
# Traing RF on the single feature PCA_6, with accuracy=0.4957 and difference=0.4294
# Traing RF on the single feature PCA_7, with accuracy=0.5161 and difference=0.4090
# Traing RF on the single feature PCA_8, with accuracy=0.5095 and difference=0.4156
# Traing RF on the single feature PCA_9, with accuracy=0.4920 and difference=0.4331
# Traing RF on the single feature PCA_10, with accuracy=0.5129 and difference=0.4122
# Traing RF on the single feature PCA_11, with accuracy=0.4980 and difference=0.4271
# Traing RF on the single feature PCA_12, with accuracy=0.5049 and difference=0.4202
# Traing RF on the single feature PCA_13, with accuracy=0.5152 and difference=0.4099
# Traing RF on the single feature PCA_14, with accuracy=0.5045 and difference=0.4206
# Traing RF on the single feature PCA_15, with accuracy=0.5047 and difference=0.4204
# Traing RF on the single feature PCA_16, with accuracy=0.5050 and difference=0.4201
# Traing RF on the single feature PCA_17, with accuracy=0.5000 and difference=0.4251
# Traing RF on the single feature PCA_18, with accuracy=0.4940 and difference=0.4311
# Traing RF on the single feature PCA_19, with accuracy=0.4898 and difference=0.4353
# Traing RF on the single feature PCA_20, with accuracy=0.4977 and difference=0.4274
# Traing RF on the single feature PCA_21, with accuracy=0.4953 and difference=0.4298
# Traing RF on the single feature PCA_22, with accuracy=0.4948 and difference=0.4303
# Traing RF on the single feature PCA_23, with accuracy=0.4988 and difference=0.4263
# Traing RF on the single feature PCA_24, with accuracy=0.4897 and difference=0.4354
# Traing RF on the single feature PCA_25, with accuracy=0.5080 and difference=0.4171
# Traing RF on the single feature PCA_26, with accuracy=0.5123 and difference=0.4128
# Traing RF on the single feature PCA_27, with accuracy=0.5052 and difference=0.4199
# Traing RF on the single feature PCA_28, with accuracy=0.5091 and difference=0.4160
# Traing RF on the single feature PCA_29, with accuracy=0.4939 and difference=0.4312
# Traing RF on the single feature PCA_30, with accuracy=0.4996 and difference=0.4255
# Traing RF on the single feature PCA_31, with accuracy=0.4922 and difference=0.4329
# Traing RF on the single feature PCA_32, with accuracy=0.5023 and difference=0.4228
# Traing RF on the single feature PCA_33, with accuracy=0.5034 and difference=0.4217
# <BarContainer object of 84 artists>
